# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/system-1.csv")

# %%
df.head()
# Out:
#    timestamp  load-1m  load-5m  load-15m  sys-mem-swap-total  \
# 0          0     0.22     0.18      0.18         16953372672
# 1         30     0.26     0.19      0.18         16953372672
# 2         60     0.16     0.17      0.18         16953372672
# 3         90     0.16     0.17      0.18         16953372672
# 4        120     0.10     0.15      0.17         16953372672
#
#    sys-mem-swap-free  sys-mem-free  sys-mem-cache  sys-mem-buffered  \
# 0        16953372672    2071302144    10307330048        1937584128
# 1        16953372672    2072969216    10307371008        1937584128
# 2        16953372672    2071818240    10307375104        1937584128
# 3        16953372672    2071830528    10307379200        1937584128
# 4        16953372672    2071859200    10307379200        1937584128
#
#    sys-mem-available  ...  sys-thermal  disk-io-time  disk-bytes-read  \
# 0        15328792576  ...         1.60        0.0076              0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85749 entries, 0 to 85748
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                85749 non-null  int64
#  1   load-1m                  85749 non-null  float64
#  2   load-5m                  85749 non-null  float64
#  3   load-15m                 85749 non-null  float64
#  4   sys-mem-swap-total       85749 non-null  int64
#  5   sys-mem-swap-free        85749 non-null  int64
#  6   sys-mem-free             85749 non-null  int64
#  7   sys-mem-cache            85749 non-null  int64
#  8   sys-mem-buffered         85749 non-null  int64
#  9   sys-mem-available        85749 non-null  int64
#  10  sys-mem-total            85749 non-null  int64
#  11  sys-fork-rate            85749 non-null  float64
#  12  sys-interrupt-rate       85749 non-null  float64
#  13  sys-context-switch-rate  85749 non-null  float64
# ...

# %%
df_cpu = df["load-1m"]
df["timestamp"] = pd.to_datetime("2024-01-01") + pd.to_timedelta(df["timestamp"], unit='s')
df_timestamp = df["timestamp"]

# %%
df_cpu.head()
# Out:
# 0    0.22
# 1    0.26
# 2    0.16
# 3    0.16
# 4    0.10
# Name: load-1m, dtype: float64

# %%
df = pd.DataFrame({"timestamp":df_timestamp, "cpu":df_cpu})

# %%
df.head()
# Out:
#             timestamp   cpu
# 0 2024-01-01 00:00:00  0.22
# 1 2024-01-01 00:00:30  0.26
# 2 2024-01-01 00:01:00  0.16
# 3 2024-01-01 00:01:30  0.16
# 4 2024-01-01 00:02:00  0.10

# %%
df.describe()
# Out:
#                            timestamp           cpu
# count                          85749  85749.000000
# mean   2024-01-15 23:20:47.412097792      0.129720
# min              2024-01-01 00:00:00      0.000000
# 25%              2024-01-08 10:38:30      0.020000
# 50%              2024-01-15 21:17:00      0.070000
# 75%              2024-01-23 13:21:30      0.160000
# max              2024-01-31 00:00:00      5.060000
# std                              NaN      0.209039

# %%
df.tail()
# Out:
#                 timestamp   cpu
# 85744 2024-01-30 23:58:00  0.17
# 85745 2024-01-30 23:58:30  0.16
# 85746 2024-01-30 23:59:00  0.10
# 85747 2024-01-30 23:59:30  0.06
# 85748 2024-01-31 00:00:00  0.18

# %%
df.isna().sum()
# Out:
# timestamp    0
# cpu          0
# dtype: int64

# %%
df.to_csv("../data/cpucycle.csv", index=False)
